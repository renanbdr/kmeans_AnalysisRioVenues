# %% [markdown]
# #**Capstone Project - Analysis of Rio de Janeiro's Centro venues**

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Importing libraries and initial data gathering](#initial)
# * [Collecting, processing and starting to visualize data](#collecting)
# * [Using Silhouete and Elbow to find the best k](#metrics)
# * [Clean visuals for our clusters & final mapping](#visuals)
# * [What can we understand from the data?](#conclusion)

# %% [markdown]
# ##**1 - Introduction**<a name="introduction"></a>

# %% [markdown]
# In this project I will be using the Foursquare API to explore and analyse different venues on Rio de Janeiro's Centro, a neighborhood known as the heart of business in the city, also home of some of the most important Museums and restaurants in the city. The idea is to provide information that could help a tourist vising the city to choose the best hotel to stay, based on the locations they decide to visit within walking distance and other preferences.

# %% [markdown]
# ##**2 - Importing libraries and initial data gathering**<a name="initial"></a>

# %% [markdown]
# here are some of the most important python libraries used on this project:

# %%
import requests
import pandas as pd
import numpy as np
import random
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

#!pip install geopy # remove the comment to install if necessary
from geopy.geocoders import Nominatim

from IPython.display import Image 
from IPython.core.display import HTML 
    
from pandas.io.json import json_normalize

#! pip install folium==0.5.0 # remove the comment to install if necessary
import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Foursquare API requests 3 different user keys when making calls to their database, the Client ID, the Client Secret and the Access Token. Those are all listed below, and since its also required for us to provide the version of the API we are trying to access, it will be listed here aswell, together with a initial queries Limit value.

# %%
CLIENT_ID = '1QQCADPYRVDCFII0L3TQQKJNHDCHTXETVHHAHLQ3VEXZI1HQ' # my Foursquare ID
CLIENT_SECRET = 'B1KIFVQLWSRCUY2OLRZBHCQWOSATB2O41L2NQGUNX3INJE54' # my Foursquare Secret
ACCESS_TOKEN = 'D35RVHULO5B1HGIGEAO31YDTOLTWAGRXQXGKWTFLGFIWTPHE' # my FourSquare Access Token
VERSION = 20180604
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

# %% [markdown]
# Here we are using the geolocator to provide coordinates used as starting point for data collection. Santos Dumont Airport was chosen for its tourist traffic and we'll expand from there.

# %%
address = 'Aeroporto Santos Dumont, Centro, Rio de Janeiro, RJ'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -22.91071875 -43.164178244974906

# %% [markdown]
# Here we're choosing 'Hotel' as our search query, which will return all hotels on a 8km radius from the airport. After the data preparation, we'll plot on a map using Folium to see if we can use them as base our data analysis.

# %%
search_query = 'Hotel'
radius = 8000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()

hoteis = results['response']['venues']
df_venues = json_normalize(hoteis)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %% [markdown]
# As you can see below, the data was sucessfully pulled, transformed into a dataframe using pandas, but it's full of unnecessary information for our current objective:

# %%
df_venues.head()

# %% [markdown]
# Let's clean this dataframe a bit by creating a new one with only the useful columns, rename them and and proceed exploring our data:

# %%
df_hoteis = pd.DataFrame([df_venues['name'],df_venues['location.lat'],df_venues['location.lng'],df_venues['location.distance']])
df_hoteis = df_hoteis.transpose()
df_hoteis['category']='Hotel'
df_hoteis.rename(columns={'location.lat':'latitude','location.lng':'longitude','location.distance':'distance'}, inplace=True)

# %%
print(df_hoteis.info())
print(df_hoteis.shape)
df_hoteis.head(30)

# %% [markdown]
# ##**3 - Collecting, Processing and starting to visualize data**<a name="collecting"></a>

# %% [markdown]
# We've done our initial data cleanup, so I think we are ready to start visualizing our starting point on the airport and nearby hotels:

# %%
airport_lat = -22.91071875
airport_lon = -43.164178244974906

map_centro = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

folium.CircleMarker(
                    [airport_lat, airport_lon],
                    radius=10,
                    popup='Santos Dumont Airport',
                    fill=True,
                    color='red',
                    fill_color='red',
                    fill_opacity=0.6).add_to(map_centro)
map_centro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_645381b2b0c143c4b6a4fb0dbc452775%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_645381b2b0c143c4b6a4fb0dbc452775%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_645381b2b0c143c4b6a4fb0dbc452775%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_645381b2b0c143c4b6a4fb0dbc452775%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_63d452f2764d43298fbf1e2849bef640%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %%
map_centro_hoteis = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

for lat, lon, name in zip(df_hoteis['latitude'],df_hoteis['longitude'],df_hoteis['name']):
    label = '{}'.format(name)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='yellow',
        fill_opacity=0.5
        ).add_to(map_centro_hoteis)

map_centro_hoteis
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_2ac58d7c65884a5faf84d89e580f00ac%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2ac58d7c65884a5faf84d89e580f00ac%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_2ac58d7c65884a5faf84d89e580f00ac%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_2ac58d7c65884a5faf84d89e580f00ac%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_5d590728cf5f4e53b52d109b67c13f87%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# ### **3.1 - Collecting venues data**
#
# Looks like the initial data is plotting correctly, so we can move on and start getting more interesting data from Foursquare API, like restaurants, bars and museums. We can repeat the search, data gathering and cleanup we did for our hotels with other venues:

# %% [markdown]
# Collecting restaurants and food venues data and adding related category column:

# %%
search_query = 'food'
limit_places = 100

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, limit_places)
results = requests.get(url).json()

food = results['response']['venues']
df_food = json_normalize(food)

df_food['category']='Food'

# %%
print(df_food.info())
print(df_food.shape)
df_food.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         50 non-null     object
#  1   name                       50 non-null     object
#  2   categories                 50 non-null     object
#  3   referralId                 50 non-null     object
#  4   hasPerk                    50 non-null     bool
#  5   location.address           28 non-null     object
#  6   location.lat               50 non-null     float64
#  7   location.lng               50 non-null     float64
#  8   location.labeledLatLngs    50 non-null     object
#  9   location.distance          50 non-null     int64
#  10  location.postalCode        19 non-null     object
#  11  location.cc                50 non-null     object
#  12  location.city              36 non-null     object
#  13  location.state             37 non-null     object
#  14  location.country           50 non-null     object
#  15  location.formattedAddress  37 non-null     object
#  16  location.crossStreet       7 non-null      object
#  17  location.neighborhood      1 non-null      object
#  18  category                   50 non-null     object
# dtypes: bool(1), float64(2), int64(1), object(15)
# memory usage: 7.2+ KB
# None
# (50, 19)
#                          id  ... category
# 0  57e59302498e6a859d6dd2df  ...     Food
# 1  56427127498e4309fc73811e  ...     Food
# 2  5e5bf05498c49900087f5703  ...     Food
# 3  5f5f6c9624ae6f671d9fe64b  ...     Food
# 4  55d34ae5498e9a38dae27fb8  ...     Food
#
# [5 rows x 19 columns]

# %% [markdown]
# Collecting Coffee shops data and adding related category column:

# %%
search_query = 'coffee'
limit_places = 100

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, limit_places)

results = requests.get(url).json()

coffee = results['response']['venues']
df_coffee = json_normalize(coffee)

df_coffee['category'] ='Coffee'

# %%
print(df_coffee.info())
print(df_coffee.shape)
df_coffee.head()

# %% [markdown]
# Collecting Bars and drinks venues data and adding related category column:

# %%
search_query = 'bar'
limit_places = 100
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, limit_places)

results = requests.get(url).json()

drinks = results['response']['venues']
df_drinks = json_normalize(drinks)

df_drinks['category'] = 'Drinks'

# %%
print(df_drinks.info())
print(df_drinks.shape)
df_drinks.head(100)

# %% [markdown]
# Collecting Museum data and adding related category column:

# %%
search_query = 'museu'
limit_places = 100
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, limit_places)

results = requests.get(url).json()

museus = results['response']['venues']
df_museus = json_normalize(museus)

df_museus['category'] = 'Museu'

# %%
print(df_museus.info())
print(df_museus.shape)
df_museus.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         50 non-null     object
#  1   name                       50 non-null     object
#  2   categories                 50 non-null     object
#  3   referralId                 50 non-null     object
#  4   hasPerk                    50 non-null     bool
#  5   location.address           45 non-null     object
#  6   location.lat               50 non-null     float64
#  7   location.lng               50 non-null     float64
#  8   location.labeledLatLngs    50 non-null     object
#  9   location.distance          50 non-null     int64
#  10  location.postalCode        40 non-null     object
#  11  location.cc                50 non-null     object
#  12  location.city              49 non-null     object
#  13  location.state             49 non-null     object
#  14  location.country           50 non-null     object
#  15  location.formattedAddress  49 non-null     object
#  16  location.crossStreet       7 non-null      object
#  17  location.neighborhood      3 non-null      object
#  18  venuePage.id               2 non-null      object
#  19  category                   50 non-null     object
# dtypes: bool(1), float64(2), int64(1), object(16)
# memory usage: 7.6+ KB
# None
# (50, 20)
#                           id  ... category
# 0   4cd6b75f89eb6dcb75e8301e  ...    Museu
# 1   4b058724f964a520ee8122e3  ...    Museu
# 2   4b058724f964a520f08122e3  ...    Museu
# 3   4dcbe46ed22d7ffe9d37b9e8  ...    Museu
# 4   4b058724f964a520fb8122e3  ...    Museu
# 5   516bfb45e4b0b4d66628e1f8  ...    Museu
# 6   57ffd84438fa38b857082ec3  ...    Museu
# 7   4ee0ebead3e38ddb2b2667f5  ...    Museu
# 8   4b058724f964a520f98122e3  ...    Museu
# 9   56741ea6498e999035b89e4c  ...    Museu
# 10  4eb6854a823131626fb46f9a  ...    Museu
# 11  4f046fac4901a1400b333a08  ...    Museu
# 12  4b9a4ae6f964a52015aa35e3  ...    Museu
# 13  4e19e123d1648b83483ffce7  ...    Museu
# 14  4ede93c80e612072e983e89b  ...    Museu
# 15  51b0e7f77dd2bc454dfb0315  ...    Museu
# 16  4ce434beb8df5481bc87b29b  ...    Museu
# 17  4b058724f964a520048222e3  ...    Museu
# 18  4db1ab245da32cf2df6154b4  ...    Museu
# 19  508921e6e4b06cb69f67a3a8  ...    Museu
# 20  4b058725f964a5200c8222e3  ...    Museu
# 21  4d7068f6c7f8224b50f3affb  ...    Museu
# 22  4b058725f964a5200e8222e3  ...    Museu
# 23  4bf52ff2ed30b713b330f49a  ...    Museu
# 24  506199eae4b0eeba838c8516  ...    Museu
# 25  4f73736be4b0bfa7ff2d0a7a  ...    Museu
# 26  51daac82498e2622c1b15d1d  ...    Museu
# 27  50b3c381e4b09a791eefef40  ...    Museu
# 28  52ebfb0e11d28ae5b1643598  ...    Museu
# 29  4c7c9e8720bb199c56932629  ...    Museu
# 30  51917bd8498eebc6a49fcba8  ...    Museu
# 31  4c8670d4d34ca1430dd74f80  ...    Museu
# 32  4e6284f5c65b2dc89fab9a17  ...    Museu
# 33  55030858498e1c8a3ed6f36e  ...    Museu
# 34  4c8bc6595e38b1f7e5042bf9  ...    Museu
# 35  4e54f1b57d8b96cd0612f240  ...    Museu
# 36  4e567442c65be3cea46621b9  ...    Museu
# 37  4db5a0fc0cb6729b6aa92d3e  ...    Museu
# 38  509d5bc5e4b09f01847fd1c1  ...    Museu
# 39  524c1ca0498e72c6f9ea3ceb  ...    Museu
# 40  4b058725f964a520058222e3  ...    Museu
# 41  51e6eed3498ebfef46f479fd  ...    Museu
# 42  59bb6f3cdb1d81620e2eec6d  ...    Museu
# 43  56054847498eb0f0608a0bcf  ...    Museu
# 44  503518cce4b0a2d03dc424b4  ...    Museu
# 45  5dffadd9117a3c000856d357  ...    Museu
# 46  5ba645b016ef670039c689e9  ...    Museu
# 47  58371f9c6b0cdb23941b7397  ...    Museu
# 48  4f5e09ece4b0b28dd640be6b  ...    Museu
# 49  57c99603498eb5f6df9611df  ...    Museu
#
# [50 rows x 20 columns]

# %% [markdown]
# Using pd.Concat to merge venues dataframes:

# %%
df_venues_concat = pd.concat([df_food, df_coffee, df_drinks, df_museus], ignore_index=True, sort=False)

# %%
print(df_venues_concat.info())
print(df_venues_concat.shape)
df_venues_concat.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         200 non-null    object
#  1   name                       200 non-null    object
#  2   categories                 200 non-null    object
#  3   referralId                 200 non-null    object
#  4   hasPerk                    200 non-null    bool
#  5   location.address           157 non-null    object
#  6   location.lat               200 non-null    float64
#  7   location.lng               200 non-null    float64
#  8   location.labeledLatLngs    200 non-null    object
#  9   location.distance          200 non-null    int64
#  10  location.postalCode        120 non-null    object
#  11  location.cc                200 non-null    object
#  12  location.city              175 non-null    object
#  13  location.state             176 non-null    object
#  14  location.country           200 non-null    object
#  15  location.formattedAddress  177 non-null    object
#  16  location.crossStreet       40 non-null     object
#  17  location.neighborhood      7 non-null      object
#  18  category                   200 non-null    object
#  19  venuePage.id               3 non-null      object
# dtypes: bool(1), float64(2), int64(1), object(16)
# memory usage: 30.0+ KB
# None
# (200, 20)
#                          id                        name  ... category venuePage.id
# 0  57e59302498e6a859d6dd2df  Mr. Fit Fast Food Saudável  ...     Food          NaN
# 1  56427127498e4309fc73811e        Joe's Pub Food Truck  ...     Food          NaN
# 2  5e5bf05498c49900087f5703             Vou Street Food  ...     Food          NaN
# 3  5f5f6c9624ae6f671d9fe64b          Kitchen Asian Food  ...     Food          NaN
# 4  55d34ae5498e9a38dae27fb8       Mix Folhas Fresh Food  ...     Food          NaN
#
# [5 rows x 20 columns]

# %% [markdown]
# Now Let's work on this dataframe to remove useless columns, rename the useful ones like we did with the hotel dataframe:

# %%
df_places = pd.DataFrame([df_venues_concat['name'],df_venues_concat['location.lat'],df_venues_concat['location.lng'],df_venues_concat['location.distance'],df_venues_concat['category']])
df_places = df_places.transpose()

df_places.rename(columns={'location.lat':'latitude','location.lng':'longitude','location.state':'state','location.distance':'distance'}, inplace=True)
df_places = df_places.astype({"distance":'int'})

# %%
print(df_places.info())
print(df_places.shape)
df_places
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 0 to 196
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       128 non-null    object
#  1   latitude   128 non-null    object
#  2   longitude  128 non-null    object
#  3   distance   128 non-null    int64
#  4   category   128 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 6.0+ KB
# None
# (128, 5)
#                                 name latitude longitude  distance category
# 0         Mr. Fit Fast Food Saudável   -22.91  -43.1712       728     Food
# 1               Joe's Pub Food Truck -22.9266  -43.1766      2180     Food
# 2                    Vou Street Food -22.9147  -43.1664       491     Food
# 3                 Kitchen Asian Food -22.9203  -43.1705      1248     Food
# 4              Mix Folhas Fresh Food -22.9051  -43.1738      1164     Food
# ..                               ...      ...       ...       ...      ...
# 190  Museu Casa de Benjamin Constant  -22.919  -43.1869      2507    Museu
# 191       Museu das Telecomunicações -22.9301  -43.1766      2508    Museu
# 194       Museu de Arte do Rio (MAR) -22.8969  -43.1818      2372    Museu
# 195             Cine Museu Do Catete  -22.926  -43.1766      2124    Museu
# 196   Junta Local Museu da República  -22.926   -43.176      2086    Museu
#
# [128 rows x 5 columns]

# %% [markdown]
# Let's plot again to check how things are going:

# %%
map_centro_analysis = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

for lat, lon, name in zip(df_places['latitude'],df_places['longitude'],df_places['name']):
    label = '{}'.format(name)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        color='purple',
        fill_color='purple',
        fill_opacity=0.5
        ).add_to(map_centro_analysis)
map_centro_analysis
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_db21d2ca7d9a4a54b622aaf10cd2a69b%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_db21d2ca7d9a4a54b622aaf10cd2a69b%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_db21d2ca7d9a4a54b622aaf10cd2a69b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_db21d2ca7d9a4a54b622aaf10cd2a69b%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_0a19bb5243a34548b9c41412bb0e19e6%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# As we could see, for some reason the API is giving us results outside the stated radius which are not all that interesting for us, so we'll drop those entries from the database.

# %%
dropdistance = df_places[df_places['distance'] > 3000].index
df_places.drop(dropdistance, inplace=True)

# %%
df_places
# Out:
#                                 name latitude longitude  distance category
# 0         Mr. Fit Fast Food Saudável   -22.91  -43.1712       728     Food
# 1               Joe's Pub Food Truck -22.9266  -43.1766      2180     Food
# 2                    Vou Street Food -22.9147  -43.1664       491     Food
# 3                 Kitchen Asian Food -22.9203  -43.1705      1248     Food
# 4              Mix Folhas Fresh Food -22.9051  -43.1738      1164     Food
# ..                               ...      ...       ...       ...      ...
# 190  Museu Casa de Benjamin Constant  -22.919  -43.1869      2507    Museu
# 191       Museu das Telecomunicações -22.9301  -43.1766      2508    Museu
# 194       Museu de Arte do Rio (MAR) -22.8969  -43.1818      2372    Museu
# 195             Cine Museu Do Catete  -22.926  -43.1766      2124    Museu
# 196   Junta Local Museu da República  -22.926   -43.176      2086    Museu
#
# [128 rows x 5 columns]

# %% [markdown]
# Finally, let's merge our venues and hotels dataframes:

# %%
df_centro = pd.concat([df_places, df_hoteis], ignore_index=True, sort=False)

# %%
print(df_centro.info())
print(df_centro.shape)
df_centro.head()

# %% [markdown]
# ## **4 - Using Silhouette and Elbow to find the best k**<a name="metrics"></a>

# %% [markdown]
# Now that we have our dataframes all set, let's now group our data points and try to find out the best k (the number of centroids) for our venues clusters:

# %% [markdown]
# We will use the Silhouette score and the Elbow Method to help us find the best number of centroids:

# %%
from sklearn.metrics import silhouette_score
sil = []
k_sil = range(2,10)
df_distance_clusters = df_centro.drop(['name','distance','category'],1)

for k in k_sil:
  kmeans = KMeans(n_clusters = k,random_state=0).fit(df_distance_clusters)
  labels = kmeans.labels_
  sil.append(silhouette_score(df_distance_clusters, labels, metric = 'euclidean'))

# %%
plt.plot(k_sil, sil, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.title('Silhouette for optimal k')
plt.show()

# %%
sqd = []
k = range(2,10)
for i in k:
  kmeans = KMeans(n_clusters=i).fit(df_distance_clusters)
  sqd.append(kmeans.inertia_)

# %%
plt.plot(k, sqd, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum of Squared Distances')
plt.title('Elbow for optimal k')
plt.show()

# %% [markdown]
# According to the scores above, k=4 would be a good approach to our clustering problem. We will have 4 well defined centroid/clusters, so lets fit the model and plot again:

# %%
k=4
kmeans = KMeans(n_clusters = k,random_state=0).fit(df_distance_clusters)
kmeans.labels_
df_centro.insert(0, 'clusterlabels', kmeans.labels_)

# %%
print(df_centro.info())
print(df_centro.shape)
df_centro

# %%
colors={0:'red',1:'blue',2:'green',3:'purple',4:'orange'}

map_centro_cluster = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

for lat, lon, clusters, name in zip(df_centro['latitude'],df_centro['longitude'],df_centro['clusterlabels'],df_centro['name']):
    label = '{}'.format(name)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        color=colors[clusters],
        fill_color=colors[clusters],
        fill_opacity=0.5
        ).add_to(map_centro_cluster)

map_centro_cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_e9a94f096f084ee68d52126b93c3aafa%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e9a94f096f084ee68d52126b93c3aafa%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_e9a94f096f084ee68d52126b93c3aafa%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_e9a94f096f084ee68d52126b93c3aafa%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_3088dbad02a8482da95db1d700821132%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# ## **5 - Clean visuals for our clusters & final mapping**<a name="visuals"></a>

# %% [markdown]
# We want this map to be easier to be more intuitive, and Font Awesome icons with Folium marker can help us with that. For that we'll need to make one more adjustment on our data. First we'll change the type of the column 'category' and then capture their codes:

# %%
df_centro = df_centro.astype({"category":'category'})
df_centro['category-id'] = df_centro['category'].cat.codes
df_centro = df_centro.astype({"category-id":'int'})

# %%
print(df_centro.info())
print(df_centro.shape)
df_centro.head(60)

# %%
icons={0:'fa-coffee', 1:'fa-glass', 2:'fa-cutlery', 3:'fa-h-square', 4:' fa-university'}

centro_marker = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

for latitude, longitude, name, clusters, category in zip(df_centro['latitude'],df_centro['longitude'],df_centro['name'], df_centro['clusterlabels'], df_centro['category-id']):
    label = '{}, Região {}'.format(name, clusters)
    folium.Marker(
        [latitude, longitude],
        popup=label,
        icon=folium.Icon(color=colors[clusters],icon=icons[category], prefix='fa')
        ).add_to(centro_marker)

centro_marker
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_51b7a79ae90244f8a0f8947c7d16a9bb%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_51b7a79ae90244f8a0f8947c7d16a9bb%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_51b7a79ae90244f8a0f8947c7d16a9bb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_51b7a79ae90244f8a0f8947c7d16a9bb%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_074e5bb83ba6408cbe08176b92146725%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# To make our final analysis easier, we can check how many different venues we have in each cluster, using GroupBy to create a new dataframe:

# %%
count_clusters = df_centro.groupby(['clusterlabels','category']).count()
count_clusters = count_clusters['category-id']
count_clusters = pd.DataFrame(count_clusters)
count_clusters.reset_index(inplace = True)
count_clusters = count_clusters.pivot_table(index = 'clusterlabels', columns ='category', values ='category-id')

# %%
count_clusters
# Out:
# category       Coffee  Drinks  Food  Hotel  Museu
# clusterlabels
# 0                   4       2     5     11      8
# 1                   3      15     3      8     13
# 2                   6      12     9      3      9
# 3                   6      14    13      8      6

# %%
count_clusters.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Clusters') # add to x-label to the plot
#plt.ylabel('') # add y-label to the plot
plt.title('Venues by clusters') # add title to the plot
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# ## **6 - What can we understand from the data?**<a name="conclusion"></a>

# %% [markdown]
# Our analysis shows that, while we have some options all around the neighborhood, some of the venues really concentrate in a few areas, while other presents good oportunities for new businesses.

# %%
centro_marker
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_51b7a79ae90244f8a0f8947c7d16a9bb%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_51b7a79ae90244f8a0f8947c7d16a9bb%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_51b7a79ae90244f8a0f8947c7d16a9bb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_51b7a79ae90244f8a0f8947c7d16a9bb%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_074e5bb83ba6408cbe08176b92146725%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# - The area nearest to the airport is a well-balanced region, with good amount of different venues and activities, which could be an interesting option for a traveler who doesn't have a lot of time and wishes to visit a couple of interesting places on foot.
# - South Region zone is the less crowded overall, but maybe that's because its located on the edge of Rio's Centro, and closer to the Zona Sul (South Zone), where some of the most famous beaches and neighborhoods like Copacabana are located. It could be a great option for those who are willing to travel a bit far and enjoy more of the City.
# - The Central Area has the most options of bars (17) and museums (12), while severely lacking on food (3) and coffee shop (3) options. This could mean a hotspot for tourists who would prefer a busy evening and lots of activities in the nigh life.
# - The northern cluster is a well-balanced area for activities, with a bit of everything, but one may find the hotel choices in the area a bit restrictive, as there are only 3 options to choose from.
#
#
# Our clusters also could help a potential investor find good spots for opening new businesses. As an example, Zone 2, the one that has the most variety of museums and nightlife, could really use more options of restaurants or food trucks.

# %% [markdown]
# #### 6.1 - Conclusion
# The purpose of this project was to map venues around Rio de Janeiro's Centro and provide a general overview to tourists coming to the city, so they would be able to make well-informed choices regarding their stay and based on their personal interests. The data gathered could also be used to indicate hotspots with bigger demand for potential new businesses around the neighborhood. For further projects, we could implement a recommender system that would allow the user to choose, via a web interface their prefered spots and receive custom suggestions for hotels and interesting venues.
